# %% [markdown]
# # UAV Person Tracker — Training
#
# Run all cells top to bottom.

# %%
# Install (Colab)
# !git clone https://github.com/YOUR_ORG/uav-person-tracker /content/repo
# !pip install -e /content/repo

# Install (Kaggle — repo already added as dataset)
# !pip install -e /kaggle/input/uav-person-tracker

# %%
# Preprocess dataset (run once)
# !uv run preprocess \
#   --dataset-root /kaggle/input/uav123/UAV123 \
#   --output-dir /kaggle/working/processed

# %%
import subprocess, sys

cmd = [
    sys.executable, "train.py",
    "--config", "configs/train.yaml",
]

# Uncomment to resume:
# cmd += ["--resume", "/kaggle/working/checkpoints/epoch_005.pth"]

subprocess.run(cmd, check=True)

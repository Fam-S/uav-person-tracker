# %% [markdown]
# # UAV Person Tracker — Training

# %%
# %cd ..
# Out:
# c:\Users\abdulhamed\Desktop\term 2\term 2\uav-person-tracker

# %%
import torch
print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("gpu:", torch.cuda.get_device_name(0))
# Out:
# torch: 2.7.1+cu126
# cuda available: True
# gpu: NVIDIA GeForce RTX 3050 Laptop GPU

# %%
# !uv run --no-sync python -c "print('start'); import torch; print('torch ok', torch.__version__)"
# !uv run --no-sync python -c "print('start'); import train.run; print('train.run import ok')"
# !uv run --no-sync python -c "from config import load_config; c=load_config('config.yaml'); print('config ok', c.train.epochs)"
# Out:
# start
# torch ok 2.7.1+cu126
# start
# train.run import ok
# config ok 20

# %%
# !uv run --no-sync train --config config.yaml \
  --override train.dataset_root=data/raw/ \
  --override train.epochs=2 \
  --override train.batch_size=8 \
  --override train.train_samples_per_epoch=512
# Out:
# ^C
